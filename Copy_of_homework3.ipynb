# %% [markdown]
# **Homework 3**

# %% [markdown]
# Problem 0.
#
# Write a recursive function that returns the product of two positive integers n and m, by adding n to itself m times.
#
# *Hints*
# 1. If m==1 then the function should just return n.
# 2. If m>1 function should return n plus the result of multiplying n and (m-1).
# 3. The result of multiplying n and m-1 is Mult(n,m-1).

# %%
def Mult(n,m):
  '''function adds n to itself, m number of times'''
  #yab

#Mult(6,6)

# %% [markdown]
# Problem 1.
#
# Write a recursive function that returns the number of vowels in a given word, W.
#
# *Hints:*
# 1. The code ```x in 'aeiou' ``` will return ```True``` if ```x``` is a vowel, and ```False``` otherwise.)
# 2. Note that the number of vowels in W is the number of vowels in W[1:], plus one if W[0] is a vowel.
# 3. The number of vowels in W[1:] is just NumVowels(W[1:]).
# 4. The number of vowels in the empty string ' ' is 0.
#
# ```
# NumVowels('Pitzer')
# > 2
# ```

# %%
def NumVowels(W):
  '''Function counts the number of vowels in the entered word'''
  #yab


#NumVowels('Mississippiiiii')

# %% [markdown]
# Problem 2.
#
# Write a recursive function ```ind(e,L)``` which returns the **index** of the first time the number e was found in the list L. If e is not in L then the function should print the message "e was not found in L".
#
# ```
# ind(2,[1,3,5,2,6])
# > 3
#
# ind(32,[0,32,0,32])
# > 1
#
# ind(7, [2,4,6,8])
# > 7 was not found in [2,4,6,8]
# ```

# %%
def ind(e,L):
  '''Function returns the index of the given number in the given list'''
  #yab


#ind(7, [2,4,6,8])

# %% [markdown]
# Problem 3.
#
# Write a recursive function ```Dot``` that take two lists of numbers, or equal length, and returns the sum of the products of the elements of the same index from each list. For example, if L=[1,2,3] and K=[4,5,6] then the function should return the number 32, because $32=1 \cdot 4+2 \cdot 5+3 \cdot 6$.
#
# Other examples:
# ```
# Dot([3],[4])
# > 12
#
# Dot([1,1],[2,7])
# 9
# ```
# *Hints:
# 1. How is Dot(L,K) related to Dot(L[1:],K[1:])?
# 2. What should happen if the lists are empty?

# %%
def Dot(L,K):
  '''Function returns the sum of the same index products from two lists of equal length'''
  #yab

#Dot([3],[4])
#Dot([1,1],[2,7])
