# %% [markdown]
# **Welcome to CS4!!! **
#
# In this first assignment, we wil explore the basics of defining functions in python. To begin, make a copy of this colab in your personal Google Drive.
#
#
# **Problem 0.**
# Complete the following function definition. The function should accept a person's first name and last name, and return a single string formatted as 'lastname, firstname'. So, for example executing
#
#
# ```
# NameFormat('David', 'Bachman')
# ```
#
# should return
# ```
# 'Bachman, David'

# %%
def NameFormat(firstname, lastname):
  '''Function to format names as Lastname, Firstname'''
  return lastname + ", " + firstname #replace this comment with the appropriate code

# %% [markdown]
# When you have completed the function definition above, run the code block by clicking the triangle on the left side of the block. Then, run the code block below to see your function in action:

# %%
NameFormat('Jimmy', 'Hendrix')
# Out:
# 'Hendrix, Jimmy'

# %% [markdown]
# **Problem 1.**
#
# Complete the following function.

# %%
def Average(x,y,z):
  '''The result should be the average of the three input numbers'''
  return (x + y + z)//3 #YOUR CODE HERE

# %% [markdown]
# Run the following code block to check your answer (the result should be 4).

# %%
Average(2,6,4)
# Out:
# 4

# %% [markdown]
# **Problem 2.**
#
# The following function should return the product of two, three, or four numbers. (Don't forget to include a docstring!)

# %%
def MultAtMostFour(a=1, b=1, c=1, d=1):
  '''The function returns the product of all the integers'''
  return a*b*c*d

# %% [markdown]
# If done correctly, the following code blocks should run without error and return the products of the input numbers.

# %%
MultAtMostFour(2,3)
# Out:
# 6

# %%
MultAtMostFour(2,3,1)
# Out:
# 6

# %%
MultAtMostFour(2,3,1,7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1e1fbf79e63a> in <cell line: 1>()
# ----> 1 MultAtMostFour(2,3,1,7)
#
# NameError: name 'MultAtMostFour' is not defined

# %% [markdown]
# Google will automatically save your work in your Google Drive. When you have completed your assignment, go to File -> Download -> Download .py to save your work in a form that can be submitted to GradeScope. The filename should be "homework0.py".

# %%
a=2
def f(x):
  x=4
  return x

print(f(a))
print(a)
# Out:
# 4
# 2

# %%
L=[0,1,2]
def f(X):
  X[1]=5
  return X

print(f(L))
print(L)
# Out:
# [0, 5, 2]
# [0, 5, 2]

# %%
S='Hello'
def f(word):
  word[0]='G'
  return word

print(f(S))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-45472fd7dcec> in <cell line: 6>()
#       4   return word
#       5
# ----> 6 print(f(S))
#
# <ipython-input-9-45472fd7dcec> in f(word)
#       1 S='Hello'
#       2 def f(word):
# ----> 3   word[0]='G'
#       4   return word
#       5
#
# TypeError: 'str' object does not support item assignment

# %%
S='Hello'
def f(word):
  word='Goodbye'
  return word

print(f(S))
# Out:
# Goodbye

# %%
a=2
def f(x):
  global a
  a=4
  return a

print(f(a))
print(a)
# Out:
# 4
# 4

# %%
a=2
def f(x):
  a=4
  return a

print(f(a))
print(a)
# Out:
# 4
# 2

# %%
S='Hello'
T=S.upper()
print(T)
print(S)
# Out:
# HELLO
# Hello

# %%
L=[2,3,1]
K=L.sort()
print(K)
print(L)
# Out:
# None
# [1, 2, 3]
